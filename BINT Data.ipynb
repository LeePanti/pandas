# %%
import pandas as pd

# %%
bint_df = pd.read_csv("BINT.csv")

# %%
bint_df
# Out:
#       STUID         DOB GENDER  ETHNICITYID  ETHNICITY  CITYID           CITY  \
# 0         1   3/20/1983      F          8.0     Creole  53,222    BELIZE CITY
# 1         1   3/20/1983      F          8.0     Creole  53,222    BELIZE CITY
# 2         1   3/20/1983      F          8.0     Creole  53,222    BELIZE CITY
# 3         1   3/20/1983      F          8.0     Creole  53,222    BELIZE CITY
# 4         1   3/20/1983      F          8.0     Creole  53,222    BELIZE CITY
# 5         1   3/20/1983      F          8.0     Creole  53,222    BELIZE CITY
# 6         1   3/20/1983      F          8.0     Creole  53,222    BELIZE CITY
# 7         1   3/20/1983      F          8.0     Creole  53,222    BELIZE CITY
# 8         1   3/20/1983      F          8.0     Creole  53,222    BELIZE CITY
# 9         1   3/20/1983      F          8.0     Creole  53,222    BELIZE CITY
# 10        1   3/20/1983      F          8.0     Creole  53,222    BELIZE CITY
# ...

# %%
ethnicity_series = pd.Series(bint_df["ETHNICITY"])

# %%
ethnicity_series.unique()
# Out:
# array(['Creole', 'Mestizo', 'Unknown', 'Oriental', 'Garifuna', 'Other',
#        'East Indian', 'Mayan', 'Caucasian', 'Ketchi', nan], dtype=object)

# %%
ethnicity_series.value_counts()
# Out:
# Mestizo        3329
# Creole         2370
# Other           689
# Unknown         528
# Oriental        444
# Garifuna        355
# Mayan           351
# East Indian     325
# Caucasian        47
# Ketchi            5
# Name: ETHNICITY, dtype: int64

# %%
feeder_series = pd.Series(bint_df["FEEDER"])

# %%
feeder_series.value_counts()
# Out:
# UNIVERSITY OF BELIZE                  3772
# ST. JOHN'S COLLEGE JUNIOR COLLEGE     1690
# SACRED HEART JUNIOR COLLEGE            543
# MUFFLES JUNIOR COLLEGE                 270
# COROZAL JUNIOR COLLEGE                 225
# ESCUELA MEXICO JR COLLEGE              198
#  WESLEY JUNIOR COLLEGE                 192
# BELMOPAN COMPREHENSIVE SCHOOL          162
# INDEPENDENCE JUNIOR COLLEGE            143
# FOREIGN                                118
#  STANN CREEK ECUMENICAL HIGH SC        118
# STANN CREEK ECUMENICAL JR. COLLEGE     112
# SACRED HEART COLLEGE                   106
# ST. CATHERINE ACADEMY                   81
# *UNKNOWN                                71
# BELMOPAN JUNIOR COLLEGE                 71
# ST. JOHN'S COLLEGE                      63
# BELIZE CHRISTIAN ACADEMY                54
# BELIZE TECHNICAL COLLEGE                49
# EDWARD P. YORKE                         48
# UNIVERSITY COLLEGE OF BELIZE            42
# BELIZE COLLEGE OF AGRICULTURE           41
# ...

# %%
bint_df.shape
# Out:
# (8444, 33)

# %%
bint_df.index
# Out:
# RangeIndex(start=0, stop=8444, step=1)

# %%
bint_df.columns
# Out:
# Index(['STUID', 'DOB', 'GENDER', 'ETHNICITYID', 'ETHNICITY', 'CITYID', 'CITY',
#        'DISTRICTID', 'DISTRICT', 'FEEDERID', 'FEEDER', 'PROGRAMSTART', 'CODE',
#        'PROGRAM', 'DEGREEID', 'DEGREE', 'PROGRAMSTATUS', 'GRADDATE',
#        'PROGRAMEND', 'BREAK', 'ENROLLEDSEMESTER', 'SEMESTERCREDITSATTEMPTED',
#        'SEMESTERCREDITSEARNED', 'SEMESTERPOINTS', 'SEMESTERGPA', 'COURSECODE',
#        'COURSETITLE', 'COURSEGRADE', 'COURSECREDITS', 'COURSEPOINTS',
#        'COURSEGPA', 'COMMENTS', 'CGPA'],
#       dtype='object')

# %%
bint_df.dtypes
# Out:
# STUID                         int64
# DOB                          object
# GENDER                       object
# ETHNICITYID                 float64
# ETHNICITY                    object
# CITYID                       object
# CITY                         object
# DISTRICTID                  float64
# DISTRICT                     object
# FEEDERID                    float64
# FEEDER                       object
# PROGRAMSTART                 object
# CODE                         object
# PROGRAM                      object
# DEGREEID                    float64
# DEGREE                       object
# PROGRAMSTATUS                object
# GRADDATE                     object
# PROGRAMEND                   object
# BREAK                        object
# ENROLLEDSEMESTER             object
# SEMESTERCREDITSATTEMPTED    float64
# SEMESTERCREDITSEARNED       float64
# SEMESTERPOINTS              float64
# SEMESTERGPA                 float64
# COURSECODE                   object
# ...

# %%
bint_df.head()
# Out:
#    STUID        DOB GENDER  ETHNICITYID ETHNICITY  CITYID         CITY  \
# 0      1  3/20/1983      F          8.0    Creole  53,222  BELIZE CITY
# 1      1  3/20/1983      F          8.0    Creole  53,222  BELIZE CITY
# 2      1  3/20/1983      F          8.0    Creole  53,222  BELIZE CITY
# 3      1  3/20/1983      F          8.0    Creole  53,222  BELIZE CITY
# 4      1  3/20/1983      F          8.0    Creole  53,222  BELIZE CITY
#
#    DISTRICTID DISTRICT  FEEDERID  ...  SEMESTERPOINTS SEMESTERGPA COURSECODE  \
# 0        75.0   BELIZE     164.0  ...             9.0         2.5    CMPS314
# 1        75.0   BELIZE     164.0  ...             7.5         2.5    CMPS316
# 2        75.0   BELIZE     164.0  ...             9.0         3.1    CMPS412
# 3        75.0   BELIZE     164.0  ...            10.5         3.5    MATH480
# 4        75.0   BELIZE     164.0  ...             7.5         2.5    CMPS312
#
#                             COURSETITLE  COURSEGRADE COURSECREDITS  \
# ...

# %%
bint_df.tail()
# Out:
#       STUID        DOB GENDER  ETHNICITYID ETHNICITY  CITYID         CITY  \
# 8439   8423  6/13/1978      F          8.0    Creole  53,222  BELIZE CITY
# 8440   8423  6/13/1978      F          8.0    Creole  53,222  BELIZE CITY
# 8441   8423  6/13/1978      F          8.0    Creole  53,222  BELIZE CITY
# 8442   8423  6/13/1978      F          8.0    Creole  53,222  BELIZE CITY
# 8443      1        NaN    NaN          NaN       NaN     NaN          NaN
#
#       DISTRICTID DISTRICT  FEEDERID  ...  SEMESTERPOINTS SEMESTERGPA  \
# 8439        75.0   BELIZE     164.0  ...             0.0         1.5
# 8440        75.0   BELIZE     164.0  ...             7.5         3.0
# 8441        75.0   BELIZE     164.0  ...            10.5         3.0
# 8442        75.0   BELIZE     164.0  ...             3.0         1.9
# 8443         NaN      NaN       NaN  ...             NaN         NaN
#
#      COURSECODE        COURSETITLE  COURSEGRADE COURSECREDITS COURSEPOINTS  \
# ...

# %%
bint_df.sample()
# Out:
#       STUID        DOB GENDER  ETHNICITYID ETHNICITY  CITYID CITY  DISTRICTID  \
# 6427   6416  3/24/1997      M         13.0   Mestizo  54,561    -        38.0
#
#          DISTRICT  FEEDERID  ...  SEMESTERPOINTS SEMESTERGPA COURSECODE  \
# 6427  STANN CREEK     164.0  ...             9.0        3.15   CMPS3232
#
#                  COURSETITLE  COURSEGRADE COURSECREDITS COURSEPOINTS  \
# 6427  SYSTEMS ADMINISTRATION            B           3.0          9.0
#
#      COURSEGPA COMMENTS  CGPA
# 6427       3.0      NaN  3.36
#
# [1 rows x 33 columns]

# %%
bint_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8444 entries, 0 to 8443
# Data columns (total 33 columns):
# STUID                       8444 non-null int64
# DOB                         8443 non-null object
# GENDER                      8443 non-null object
# ETHNICITYID                 8443 non-null float64
# ETHNICITY                   8443 non-null object
# CITYID                      8426 non-null object
# CITY                        8328 non-null object
# DISTRICTID                  8426 non-null float64
# DISTRICT                    8426 non-null object
# FEEDERID                    8325 non-null float64
# FEEDER                      8325 non-null object
# PROGRAMSTART                8443 non-null object
# CODE                        8443 non-null object
# PROGRAM                     8443 non-null object
# DEGREEID                    8443 non-null float64
# DEGREE                      8443 non-null object
# PROGRAMSTATUS               8443 non-null object
# ...

# %%
bint_df.tail(1)
# Out:
#       STUID  DOB GENDER  ETHNICITYID ETHNICITY CITYID CITY  DISTRICTID  \
# 8443      1  NaN    NaN          NaN       NaN    NaN  NaN         NaN
#
#      DISTRICT  FEEDERID ...  SEMESTERPOINTS SEMESTERGPA COURSECODE  \
# 8443      NaN       NaN ...             NaN         NaN        NaN
#
#      COURSETITLE  COURSEGRADE COURSECREDITS COURSEPOINTS COURSEGPA COMMENTS  \
# 8443         NaN          NaN           NaN          NaN       NaN      NaN
#
#      CGPA
# 8443  NaN
#
# [1 rows x 33 columns]

# %%
bint_df.describe()
# Out:
#              STUID  ETHNICITYID   DISTRICTID     FEEDERID  DEGREEID  \
# count  8444.000000   8443.00000  8426.000000  8325.000000    8443.0
# mean   4209.436168     11.64361   209.493710   153.162763      13.0
# std    2438.497473      2.71279   164.882259    16.991710       0.0
# min       1.000000      7.00000    25.000000    91.000000      13.0
# 25%    2107.000000      8.00000    75.000000   152.000000      13.0
# 50%    4213.500000     13.00000    75.000000   164.000000      13.0
# 75%    6328.000000     13.00000   393.000000   164.000000      13.0
# max    8423.000000     16.00000   499.000000   172.000000      13.0
#
#        SEMESTERCREDITSATTEMPTED  SEMESTERCREDITSEARNED  SEMESTERPOINTS  \
# count               8443.000000            8212.000000     8207.000000
# mean                   3.247661               3.079031        9.088339
# std                    1.601836               1.712844        7.142712
# ...

# %%
bint_df.columns
# Out:
# Index(['STUID', 'DOB', 'GENDER', 'ETHNICITYID', 'ETHNICITY', 'CITYID', 'CITY',
#        'DISTRICTID', 'DISTRICT', 'FEEDERID', 'FEEDER', 'PROGRAMSTART', 'CODE',
#        'PROGRAM', 'DEGREEID', 'DEGREE', 'PROGRAMSTATUS', 'GRADDATE',
#        'PROGRAMEND', 'BREAK', 'ENROLLEDSEMESTER', 'SEMESTERCREDITSATTEMPTED',
#        'SEMESTERCREDITSEARNED', 'SEMESTERPOINTS', 'SEMESTERGPA', 'COURSECODE',
#        'COURSETITLE', 'COURSEGRADE', 'COURSECREDITS', 'COURSEPOINTS',
#        'COURSEGPA', 'COMMENTS', 'CGPA'],
#       dtype='object')

# %%
bint_df.loc[:5, "STUID":"GENDER"]
# Out:
#    STUID        DOB GENDER
# 0      1  3/20/1983      F
# 1      1  3/20/1983      F
# 2      1  3/20/1983      F
# 3      1  3/20/1983      F
# 4      1  3/20/1983      F
# 5      1  3/20/1983      F

# %%
bint_df.drop("STUID", axis = 1)
# Out:
#              DOB GENDER  ETHNICITYID  ETHNICITY  CITYID           CITY  \
# 0      3/20/1983      F          8.0     Creole  53,222    BELIZE CITY
# 1      3/20/1983      F          8.0     Creole  53,222    BELIZE CITY
# 2      3/20/1983      F          8.0     Creole  53,222    BELIZE CITY
# 3      3/20/1983      F          8.0     Creole  53,222    BELIZE CITY
# 4      3/20/1983      F          8.0     Creole  53,222    BELIZE CITY
# 5      3/20/1983      F          8.0     Creole  53,222    BELIZE CITY
# 6      3/20/1983      F          8.0     Creole  53,222    BELIZE CITY
# 7      3/20/1983      F          8.0     Creole  53,222    BELIZE CITY
# 8      3/20/1983      F          8.0     Creole  53,222    BELIZE CITY
# 9      3/20/1983      F          8.0     Creole  53,222    BELIZE CITY
# 10     3/20/1983      F          8.0     Creole  53,222    BELIZE CITY
# 11     3/20/1983      F          8.0     Creole  53,222    BELIZE CITY
# ...

# %%
bint_df.drop(["ETHNICITYID", "CITYID", "DISTRICTID", "FEEDERID"], axis = 1, inplace = True)

# %%
bint_df
# Out:
#       STUID         DOB GENDER  ETHNICITY           CITY     DISTRICT  \
# 0         1   3/20/1983      F     Creole    BELIZE CITY       BELIZE
# 1         1   3/20/1983      F     Creole    BELIZE CITY       BELIZE
# 2         1   3/20/1983      F     Creole    BELIZE CITY       BELIZE
# 3         1   3/20/1983      F     Creole    BELIZE CITY       BELIZE
# 4         1   3/20/1983      F     Creole    BELIZE CITY       BELIZE
# 5         1   3/20/1983      F     Creole    BELIZE CITY       BELIZE
# 6         1   3/20/1983      F     Creole    BELIZE CITY       BELIZE
# 7         1   3/20/1983      F     Creole    BELIZE CITY       BELIZE
# 8         1   3/20/1983      F     Creole    BELIZE CITY       BELIZE
# 9         1   3/20/1983      F     Creole    BELIZE CITY       BELIZE
# 10        1   3/20/1983      F     Creole    BELIZE CITY       BELIZE
# 11        1   3/20/1983      F     Creole    BELIZE CITY       BELIZE
# ...

# %%
bint_df.drop([8443], axis = 0, inplace = True)

# %%
bint_df.shape
# Out:
# (8443, 29)

# %%
bint_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8443 entries, 0 to 8442
# Data columns (total 29 columns):
# STUID                       8443 non-null int64
# DOB                         8443 non-null object
# GENDER                      8443 non-null object
# ETHNICITY                   8443 non-null object
# CITY                        8328 non-null object
# DISTRICT                    8426 non-null object
# FEEDER                      8325 non-null object
# PROGRAMSTART                8443 non-null object
# CODE                        8443 non-null object
# PROGRAM                     8443 non-null object
# DEGREEID                    8443 non-null float64
# DEGREE                      8443 non-null object
# PROGRAMSTATUS               8443 non-null object
# GRADDATE                    5455 non-null object
# PROGRAMEND                  5607 non-null object
# BREAK                       8443 non-null object
# ENROLLEDSEMESTER            8443 non-null object
# ...

# %%
bint_df.nunique()
# Out:
# STUID                       436
# DOB                         426
# GENDER                        2
# ETHNICITY                    10
# CITY                         48
# DISTRICT                      8
# FEEDER                       31
# PROGRAMSTART                 86
# CODE                          2
# PROGRAM                       1
# DEGREEID                      1
# DEGREE                        1
# PROGRAMSTATUS                 6
# GRADDATE                     35
# PROGRAMEND                   53
# BREAK                         1
# ENROLLEDSEMESTER             65
# SEMESTERCREDITSATTEMPTED      6
# SEMESTERCREDITSEARNED         6
# SEMESTERPOINTS               30
# SEMESTERGPA                 167
# COURSECODE                  241
# COURSETITLE                 189
# COURSEGRADE                  17
# COURSECREDITS                 6
# COURSEPOINTS                 30
# COURSEGPA                    10
# COMMENTS                      1
# CGPA                        173
# ...

# %%
bint_df.duplicated(subset = "STUID")
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12       True
# 13       True
# 14       True
# 15       True
# 16       True
# 17       True
# 18      False
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24       True
# 25       True
# 26       True
# 27       True
# 28       True
# 29       True
#         ...
# 8413     True
# 8414     True
# 8415     True
# 8416     True
# 8417     True
# 8418     True
# 8419     True
# 8420     True
# 8421     True
# 8422    False
# 8423     True
# 8424     True
# 8425     True
# 8426     True
# 8427     True
# 8428     True
# 8429     True
# 8430     True
# 8431     True
# 8432     True
# 8433     True
# 8434     True
# 8435     True
# 8436     True
# 8437     True
# 8438     True
# 8439     True
# 8440     True
# 8441     True
# 8442     True
# ...

# %%
gender = bint_df.drop_duplicates(subset = "STUID", keep = "last")

# %%
gender.groupby("GENDER")["GENDER"].count()
# Out:
# GENDER
# F     97
# M    339
# Name: GENDER, dtype: int64

# %%
ethnicity = bint_df.drop_duplicates(subset = "STUID", keep = "last")

# %%
ethnicity.groupby("ETHNICITY")["ETHNICITY"].count()
# Out:
# ETHNICITY
# Caucasian        2
# Creole         118
# East Indian     15
# Garifuna        19
# Ketchi           1
# Mayan           15
# Mestizo        175
# Oriental        23
# Other           40
# Unknown         28
# Name: ETHNICITY, dtype: int64

# %%
feeder = bint_df.drop_duplicates(subset = "STUID", keep = "last")

# %%
feeder.groupby("FEEDER")["FEEDER"].count()
# Out:
# FEEDER
#  STANN CREEK ECUMENICAL HIGH SC         6
#  WESLEY JUNIOR COLLEGE                 10
# *UNKNOWN                                8
# ADULT & CONTINUING EDUCATION            1
# BELIZE ADVENTIST COLLEGE                3
# BELIZE ADVENTIST JUNIOR COLLEGE         4
# BELIZE CHRISTIAN ACADEMY                3
# BELIZE COLLEGE OF AGRICULTURE           1
# BELIZE TECHNICAL COLLEGE                3
# BELMOPAN COMPREHENSIVE SCHOOL           9
# BELMOPAN JUNIOR COLLEGE                 4
# COROZAL JUNIOR COLLEGE                 12
# EDEN SDA HIGH                           1
# EDWARD P. YORKE                         2
# ESCUELA MEXICO JR COLLEGE              13
# FOREIGN                                 8
# INDEPENDENCE JUNIOR COLLEGE             7
# LADYVILLE TECHNICAL HIGH                1
# MOPAN TECHNICAL HIGH SCHOOL             1
# MUFFLES JUNIOR COLLEGE                 10
# OUR LADY OF GUADALUPE HIGH SCH          1
# SACRED HEART COLLEGE                    5
# ...

# %%
district = bint_df.drop_duplicates(subset = "STUID", keep = "last")

# %%
district.groupby("DISTRICT")["DISTRICT"].count()
# Out:
# DISTRICT
# 465              1
# BELIZE         152
# CAYO           173
# COROZAL         24
# NIGERIA          2
# ORANGE WALK     40
# STANN CREEK     34
# TOLEDO           9
# Name: DISTRICT, dtype: int64

# %%
bint_df.groupby("STUID")["CGPA"].mean()
# Out:
# STUID
# 1       3.260
# 19      3.320
# 56      1.330
# 105     3.620
# 109     1.230
# 120     3.290
# 138     2.000
# 141     3.710
# 158     3.500
# 172     3.770
# 189     3.094
# 204     3.200
# 227     3.520
# 246     3.260
# 265     1.750
# 270     2.550
# 292     3.200
# 310     3.350
# 343     3.010
# 384     3.110
# 408     1.170
# 414     2.250
# 417     1.980
# 437     3.360
# 465     3.250
# 496       NaN
# 498     2.680
# 512     1.500
# 520     3.810
# 555     2.810
#         ...
# 8006    3.140
# 8033    3.500
# 8044    0.950
# 8064    0.000
# 8071    3.380
# 8082    2.700
# 8092      NaN
# 8096    2.500
# 8109    3.170
# 8121    2.680
# 8133    3.010
# 8154    2.300
# 8160    3.080
# 8170    3.490
# 8191    2.000
# 8200    2.630
# 8220    2.950
# 8232    3.420
# 8235    1.830
# 8244    2.800
# 8254    2.960
# 8266    2.130
# 8273    3.810
# 8304    1.500
# 8311    2.950
# 8322    2.940
# 8340    3.080
# 8368    3.050
# 8394    3.730
# 8423    2.010
# ...
